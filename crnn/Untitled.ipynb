# %%
# 2020-09-29 裸CRNN训练1
# Out:
# ...
# Train Epoch: 2 Loss: 1.745164: 100%|██████████| 311/311 [01:08<00:00,  4.55it/s]
#
# loss               1.401958
# accuracy           0.508307
# avg_precision      0.444333
# avg_recall         0.458884
# val_loss           1.390346
# val_accuracy       0.564951
# val_avg_precision  0.510810
# val_avg_recall     0.489489
# lr_0: 0.002
#
# Run TensorboardX:
# tensorboard --logdir=saved_cv/0929_102705\logs
#
# Saving checkpoint: saved_cv/0929_102705\checkpoints\checkpoint-current.pth ...
# Saving current best: model_best.pth ...
# [IMPROVED]
#
# ...
# Train Epoch: 3 Loss: 1.617635:  51%|█████     | 159/311 [00:34<00:34,  4.47it/s]
# ...
# ...
# Train Epoch: 42 Loss: 0.500136: 100%|██████████| 311/311 [01:07<00:00,  4.60it/s]
#
# loss               0.748683
# accuracy           0.759110
# avg_precision      0.676547
# avg_recall         0.676481
# val_loss           1.075226
# val_accuracy       0.667892
# val_avg_precision  0.578936
# val_avg_recall     0.563522
# lr_0: 0.000125
# ...
